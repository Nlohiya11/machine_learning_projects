# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import requests
from bs4 import BeautifulSoup

# %%
name = []
year = []
rating = []
runtime = []
certificate = []
genre = []
movie_director=[]
stars = []
metascore = []
image=[]
description = []
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
for i in range(0,200):
    webpage= ""
    string = requests.get(f'https://www.imdb.com/search/title/?title_type=feature&year=1972-01-01,&sort=num_votes,desc&start={i*50+1}&ref_=adv_nxt', headers =headers).text
    webpage = string + webpage
    soup = BeautifulSoup(webpage, 'html.parser')
    movies = soup.find_all('div', class_ = 'lister-item mode-advanced')
    for info in movies:
        i = info.find('h3', class_='lister-item-header').text.strip()
        name.append(i.split('\n')[1])
        try:
            try:
                year.append(int(i.split('\n')[2].split('(')[1].replace('(','').replace(')','')))
            except:
                year.append(int(i.split('\n')[2].split('(')[2].replace('(','').replace(')','')))
        except:
            year.append(np.nan)
        try:
            rating.append(float(info.find('div', class_='inline-block ratings-imdb-rating').text.strip()))
        except:
            rating.append(np.nan)
        try:
            runtime.append(int(info.find('span', class_='runtime').text.strip().split(' ')[0]))
        except:
            runtime.append(np.nan)
        try:
            certificate.append(info.find('span', class_='certificate').text.strip().split(' ')[0])
        except:
            certificate.append(np.nan)
        try:
            genre.append(info.find('span', class_='genre').text.strip())
        except:
            genre.append(np.nan)
        try:
            metascore.append(info.find('div', class_='inline-block ratings-metascore').text.strip().split()[0])
        except:
            metascore.append(np.nan)
        tit = info.find('p',class_='').text.strip()
        try:
            stars.append(tit.split('Stars:\n')[1].replace('\n',''))
        except:
            stars.append(np.nan)
        try:
            sat =tit.split('|')[0].split(':')
            if sat[0]=='Director' or sat[0]=='Directors':
                director=''.join(sat[1:])
                movie_director.append(director.replace('\n',''))
            else:
                movie_director.append(np.nan)
        except:
            movie_director.append(np.nan)
        try:
            image.append(info.find('img').get('loadlate'))
        except:
            image.append(np.nan)
    krt = soup.find_all('p',class_="text-muted")
    count = 0
    for i in krt:
        if count % 2 == 1:
            try:
                description.append(i.text.strip())
            except:
                description.append(np.nan)
        count += 1

    print(len(name),len(year),len(rating),len(runtime),len(certificate),len(genre),len(metascore),len(movie_director),len(stars))
# Out:
# 50 50 50 50 50 50 50 50 50
# 100 100 100 100 100 100 100 100 100
# 150 150 150 150 150 150 150 150 150
# 200 200 200 200 200 200 200 200 200
# 250 250 250 250 250 250 250 250 250
# 300 300 300 300 300 300 300 300 300
# 350 350 350 350 350 350 350 350 350
# 400 400 400 400 400 400 400 400 400
# 450 450 450 450 450 450 450 450 450
# 500 500 500 500 500 500 500 500 500
# 550 550 550 550 550 550 550 550 550
# 600 600 600 600 600 600 600 600 600
# 650 650 650 650 650 650 650 650 650
# 700 700 700 700 700 700 700 700 700
# 750 750 750 750 750 750 750 750 750
# 800 800 800 800 800 800 800 800 800
# 850 850 850 850 850 850 850 850 850
# 900 900 900 900 900 900 900 900 900
# 950 950 950 950 950 950 950 950 950
# 1000 1000 1000 1000 1000 1000 1000 1000 1000
# 1050 1050 1050 1050 1050 1050 1050 1050 1050
# 1100 1100 1100 1100 1100 1100 1100 1100 1100
# 1150 1150 1150 1150 1150 1150 1150 1150 1150
# 1200 1200 1200 1200 1200 1200 1200 1200 1200
# 1250 1250 1250 1250 1250 1250 1250 1250 1250
# ...

# %%
def create_movies(website):
    website = website.replace('start=1','start={a[i*50+1]}')
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    for i in range(0,150):
        webpage= ""
        string = requests.get(website.format(a={'i*50+1':i*50+1}), headers =headers).text
        webpage = string + webpage
        soup = BeautifulSoup(webpage, 'html.parser')
        movies = soup.find_all('div', class_ = 'lister-item mode-advanced')
        for info in movies:
            i = info.find('h3', class_='lister-item-header').text.strip()
            name.append(i.split('\n')[1])
            try:
                try:
                    year.append(int(i.split('\n')[2].split('(')[1].replace('(','').replace(')','')))
                except:
                    year.append(int(i.split('\n')[2].split('(')[2].replace('(','').replace(')','')))
            except:
                year.append(np.nan)
            try:
                rating.append(float(info.find('div', class_='inline-block ratings-imdb-rating').text.strip()))
            except:
                rating.append(np.nan)
            try:
                runtime.append(int(info.find('span', class_='runtime').text.strip().split(' ')[0]))
            except:
                runtime.append(np.nan)
            try:
                certificate.append(info.find('span', class_='certificate').text.strip().split(' ')[0])
            except:
                certificate.append(np.nan)
            try:
                genre.append(info.find('span', class_='genre').text.strip())
            except:
                genre.append(np.nan)
            try:
                metascore.append(info.find('div', class_='inline-block ratings-metascore').text.strip().split()[0])
            except:
                metascore.append(np.nan)
            tit = info.find('p',class_='').text.strip()
            try:
                stars.append(tit.split('Stars:\n')[1].replace('\n',''))
            except:
                stars.append(np.nan)
            try:
                sat =tit.split('|')[0].split(':')
                if sat[0]=='Director' or sat[0]=='Directors':
                    director=''.join(sat[1:])
                    movie_director.append(director.replace('\n',''))
                else:
                    movie_director.append(np.nan)
            except:
                movie_director.append(np.nan)
            try:
                image.append(info.find('img').get('loadlate'))
            except:
                image.append(np.nan)
        krt = soup.find_all('p',class_="text-muted")
        count = 0
        for i in krt:
            if count % 2 == 1:
                try:
                    description.append(i.text.strip())
                except:
                    description.append(np.nan)
            count += 1

        print(len(name),len(year),len(rating),len(runtime),len(certificate),len(genre),len(metascore),len(movie_director),len(stars))

# %%
create_movies('https://www.imdb.com/search/title/?title_type=feature&year=2021-01-01,2021-12-12&start=1&ref_=adv_nxt')
# Out:
# 10050 10050 10050 10050 10050 10050 10050 10050 10050
# 10100 10100 10100 10100 10100 10100 10100 10100 10100
# 10150 10150 10150 10150 10150 10150 10150 10150 10150
# 10200 10200 10200 10200 10200 10200 10200 10200 10200
# 10250 10250 10250 10250 10250 10250 10250 10250 10250
# 10300 10300 10300 10300 10300 10300 10300 10300 10300
# 10350 10350 10350 10350 10350 10350 10350 10350 10350
# 10400 10400 10400 10400 10400 10400 10400 10400 10400
# 10450 10450 10450 10450 10450 10450 10450 10450 10450
# 10500 10500 10500 10500 10500 10500 10500 10500 10500
# 10550 10550 10550 10550 10550 10550 10550 10550 10550
# 10600 10600 10600 10600 10600 10600 10600 10600 10600
# 10650 10650 10650 10650 10650 10650 10650 10650 10650
# 10700 10700 10700 10700 10700 10700 10700 10700 10700
# 10750 10750 10750 10750 10750 10750 10750 10750 10750
# 10800 10800 10800 10800 10800 10800 10800 10800 10800
# 10850 10850 10850 10850 10850 10850 10850 10850 10850
# ...

# %%
create_movies(f'https://www.imdb.com/search/title/?title_type=feature&year=2001-01-01,2010-12-12&start=1&ref_=adv_nxt')
# Out:
# 17550 17550 17550 17550 17550 17550 17550 17550 17550
# 17600 17600 17600 17600 17600 17600 17600 17600 17600
# 17650 17650 17650 17650 17650 17650 17650 17650 17650
# 17700 17700 17700 17700 17700 17700 17700 17700 17700
# 17750 17750 17750 17750 17750 17750 17750 17750 17750
# 17800 17800 17800 17800 17800 17800 17800 17800 17800
# 17850 17850 17850 17850 17850 17850 17850 17850 17850
# 17900 17900 17900 17900 17900 17900 17900 17900 17900
# 17950 17950 17950 17950 17950 17950 17950 17950 17950
# 18000 18000 18000 18000 18000 18000 18000 18000 18000
# 18050 18050 18050 18050 18050 18050 18050 18050 18050
# 18100 18100 18100 18100 18100 18100 18100 18100 18100
# 18150 18150 18150 18150 18150 18150 18150 18150 18150
# 18200 18200 18200 18200 18200 18200 18200 18200 18200
# 18250 18250 18250 18250 18250 18250 18250 18250 18250
# 18300 18300 18300 18300 18300 18300 18300 18300 18300
# 18350 18350 18350 18350 18350 18350 18350 18350 18350
# ...

# %%
create_movies(f'https://www.imdb.com/search/title/?title_type=feature&year=2011-01-01,2015-12-12&start=1&ref_=adv_nxt')
# Out:
# 25050 25050 25050 25050 25050 25050 25050 25050 25050
# 25100 25100 25100 25100 25100 25100 25100 25100 25100
# 25150 25150 25150 25150 25150 25150 25150 25150 25150
# 25200 25200 25200 25200 25200 25200 25200 25200 25200
# 25250 25250 25250 25250 25250 25250 25250 25250 25250
# 25300 25300 25300 25300 25300 25300 25300 25300 25300
# 25350 25350 25350 25350 25350 25350 25350 25350 25350
# 25400 25400 25400 25400 25400 25400 25400 25400 25400
# 25450 25450 25450 25450 25450 25450 25450 25450 25450
# 25500 25500 25500 25500 25500 25500 25500 25500 25500
# 25550 25550 25550 25550 25550 25550 25550 25550 25550
# 25600 25600 25600 25600 25600 25600 25600 25600 25600
# 25650 25650 25650 25650 25650 25650 25650 25650 25650
# 25700 25700 25700 25700 25700 25700 25700 25700 25700
# 25750 25750 25750 25750 25750 25750 25750 25750 25750
# 25800 25800 25800 25800 25800 25800 25800 25800 25800
# 25850 25850 25850 25850 25850 25850 25850 25850 25850
# ...

# %%
create_movies(f'https://www.imdb.com/search/title/?title_type=feature&year=2016-01-01,2020-12-12&start=1&ref_=adv_nxt')
# Out:
# 32550 32550 32550 32550 32550 32550 32550 32550 32550
# 32600 32600 32600 32600 32600 32600 32600 32600 32600
# 32650 32650 32650 32650 32650 32650 32650 32650 32650
# 32700 32700 32700 32700 32700 32700 32700 32700 32700
# 32750 32750 32750 32750 32750 32750 32750 32750 32750
# 32800 32800 32800 32800 32800 32800 32800 32800 32800
# 32850 32850 32850 32850 32850 32850 32850 32850 32850
# 32900 32900 32900 32900 32900 32900 32900 32900 32900
# 32950 32950 32950 32950 32950 32950 32950 32950 32950
# 33000 33000 33000 33000 33000 33000 33000 33000 33000
# 33050 33050 33050 33050 33050 33050 33050 33050 33050
# 33100 33100 33100 33100 33100 33100 33100 33100 33100
# 33150 33150 33150 33150 33150 33150 33150 33150 33150
# 33200 33200 33200 33200 33200 33200 33200 33200 33200
# 33250 33250 33250 33250 33250 33250 33250 33250 33250
# 33300 33300 33300 33300 33300 33300 33300 33300 33300
# 33350 33350 33350 33350 33350 33350 33350 33350 33350
# ...

# %%
create_movies(f'https://www.imdb.com/search/title/?title_type=feature&year=2022-01-01,2023-08-21&start=1&ref_=adv_nxt')
# Out:
# 40050 40050 40050 40050 40050 40050 40050 40050 40050
# 40100 40100 40100 40100 40100 40100 40100 40100 40100
# 40150 40150 40150 40150 40150 40150 40150 40150 40150
# 40200 40200 40200 40200 40200 40200 40200 40200 40200
# 40250 40250 40250 40250 40250 40250 40250 40250 40250
# 40300 40300 40300 40300 40300 40300 40300 40300 40300
# 40350 40350 40350 40350 40350 40350 40350 40350 40350
# 40400 40400 40400 40400 40400 40400 40400 40400 40400
# 40450 40450 40450 40450 40450 40450 40450 40450 40450
# 40500 40500 40500 40500 40500 40500 40500 40500 40500
# 40550 40550 40550 40550 40550 40550 40550 40550 40550
# 40600 40600 40600 40600 40600 40600 40600 40600 40600
# 40650 40650 40650 40650 40650 40650 40650 40650 40650
# 40700 40700 40700 40700 40700 40700 40700 40700 40700
# 40750 40750 40750 40750 40750 40750 40750 40750 40750
# 40800 40800 40800 40800 40800 40800 40800 40800 40800
# 40850 40850 40850 40850 40850 40850 40850 40850 40850
# ...

# %%
dictionary = {'Movie': name,'Released': year,'Rating': rating,'Movie_runtime':runtime,'Certified': certificate,'Genre': genre,'Metascore': metascore,'Movie_director': movie_director,'Stars':stars,'Description' : description,'Image' : image}

# %%
df = pd.DataFrame(dictionary)
df.tail(20)
# Out:
#                                             Movie  Released  Rating  \
# 47480             Johannes ei kulje Jämsän kautta    2023.0     6.6
# 47481                    When George Got Murdered    2022.0     7.9
# 47482                                  Spellbound    2023.0     NaN
# 47483  Zhong guo qing nian: Wo he wo de qing chun    2023.0     7.0
# 47484                           Beneath the Green    2022.0     3.4
# 47485                        A Song from the Dark    2023.0     NaN
# 47486                        Aathva Rang Premacha    2022.0     8.2
# 47487                                 Sher Gujjar    2022.0     8.1
# 47488                                  Ready Cash    2023.0     NaN
# 47489       The Key -Professor's Pleasure- (Kagi)    2022.0     8.0
# 47490                      Kallanum Bhagavathiyum    2023.0     6.2
# 47491                                   NRI Wives    2023.0     7.2
# 47492                                        Yosi    2023.0     9.4
# ...

# %%
df.duplicated().sum()
# Out:
# 6976

# %%
df = df.drop_duplicates()
df
# Out:
#                                 Movie  Released  Rating  Movie_runtime  \
# 0            The Shawshank Redemption    1994.0     9.3          142.0
# 1                     The Dark Knight    2008.0     9.0          152.0
# 2                           Inception    2010.0     8.8          148.0
# 3                          Fight Club    1999.0     8.8          139.0
# 4                        Forrest Gump    1994.0     8.8          142.0
# ...                               ...       ...     ...            ...
# 47495                  Before You Die    2022.0     8.3            NaN
# 47496  Tina & Bettina 2: The Comeback    2023.0     5.0           90.0
# 47497              Woman in the Chair    2022.0     5.1            NaN
# 47498                        Chrzciny    2022.0     5.9           88.0
# 47499                          Barren    2022.0     8.0          108.0
#
#       Certified                      Genre Metascore       Movie_director  \
# ...

# %%
df.to_csv('Films2.csv')

# %%
df = pd.read_csv('Films2.csv')

# %%
df.shape
# Out:
# (40524, 12)

# %%
df.describe()
# Out:
#          Unnamed: 0      Released        Rating  Movie_runtime     Metascore
# count  40524.000000  40517.000000  38203.000000   38021.000000  12574.000000
# mean   23452.044393   2014.229262      5.985399     103.305384     55.933752
# std    14480.130257      9.257136      1.352948      23.185477     17.320990
# min        0.000000   1972.000000      1.000000       1.000000      1.000000
# 25%    10366.750000   2010.000000      5.200000      90.000000     44.000000
# 50%    23310.500000   2017.000000      6.100000      99.000000     57.000000
# 75%    36876.250000   2021.000000      6.900000     114.000000     69.000000
# max    47499.000000   2023.000000     10.000000     808.000000    100.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Movie                 0
# Released              7
# Rating             2321
# Movie_runtime      2503
# Certified         24403
# Genre               314
# Metascore         27950
# Movie_director      248
# Stars               457
# Description           0
# Image                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40524 entries, 0 to 40523
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      40524 non-null  int64
#  1   Movie           40524 non-null  object
#  2   Released        40517 non-null  float64
#  3   Rating          38203 non-null  float64
#  4   Movie_runtime   38021 non-null  float64
#  5   Certified       16121 non-null  object
#  6   Genre           40210 non-null  object
#  7   Metascore       12574 non-null  float64
#  8   Movie_director  40276 non-null  object
#  9   Stars           40067 non-null  object
#  10  Description     40524 non-null  object
#  11  Image           40524 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 3.7+ MB

# %%
df['Certified'].unique()
# Out:
# array(['A', 'UA', 'U', 'R', '15+', '18', '13', '12+', '16', '(Banned)',
#        'PG', 'PG-13', nan, 'U/A', '7', 'All', 'Not', '12', 'Unrated',
#        '18+', 'G', 'NC-17', '16+', '7+', 'GP', '13+'], dtype=object)

# %%
df['Certified']=df['Certified'].map({'R':'R', '15+':'U/A', '18':'A', '13':'U/A', '12+':'U/A', '16':'A',
       'PG':'U', 'PG-13':'U/A','UA':'U/A', '7':'U', 'All':'U', 'Not':'A', '12':'U/A','(Banned)':'R','Unrated':'U/A',
       '18+':'A', 'G':'U', 'NC-17':'A', '16+':'A', '7+':'U', 'GP':'U'})

# %%
df['Certified'].unique()
# Out:
# array([nan, 'U/A', 'R', 'A', 'U'], dtype=object)

# %%
df['Certified'] =df['Certified'].fillna('U/A')

# %%
df['Certified'].unique()
# Out:
# array(['U/A', 'R', 'A', 'U'], dtype=object)

# %%
df
# Out:
#        Unnamed: 0                           Movie  Released  Rating  \
# 0               0        The Shawshank Redemption    1994.0     9.3
# 1               1                 The Dark Knight    2008.0     9.0
# 2               2                       Inception    2010.0     8.8
# 3               3                      Fight Club    1999.0     8.8
# 4               4                    Forrest Gump    1994.0     8.8
# ...           ...                             ...       ...     ...
# 40519       47495                  Before You Die    2022.0     8.3
# 40520       47496  Tina & Bettina 2: The Comeback    2023.0     5.0
# 40521       47497              Woman in the Chair    2022.0     5.1
# 40522       47498                        Chrzciny    2022.0     5.9
# 40523       47499                          Barren    2022.0     8.0
#
#        Movie_runtime Certified                      Genre  Metascore  \
# 0              142.0       U/A                      Drama       82.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40524 entries, 0 to 40523
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      40524 non-null  int64
#  1   Movie           40524 non-null  object
#  2   Released        40517 non-null  float64
#  3   Rating          38203 non-null  float64
#  4   Movie_runtime   38021 non-null  float64
#  5   Certified       40524 non-null  object
#  6   Genre           40210 non-null  object
#  7   Metascore       12574 non-null  float64
#  8   Movie_director  40276 non-null  object
#  9   Stars           40067 non-null  object
#  10  Description     40524 non-null  object
#  11  Image           40524 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 3.7+ MB

# %%
df.rename(columns={'Movie':'Title','Released':'Year_of_Release'},inplace = True)

# %%
df.describe()
# Out:
#          Unnamed: 0  Year_of_Release        Rating  Movie_runtime  \
# count  40524.000000     40517.000000  38203.000000   38021.000000
# mean   23452.044393      2014.229262      5.985399     103.305384
# std    14480.130257         9.257136      1.352948      23.185477
# min        0.000000      1972.000000      1.000000       1.000000
# 25%    10366.750000      2010.000000      5.200000      90.000000
# 50%    23310.500000      2017.000000      6.100000      99.000000
# 75%    36876.250000      2021.000000      6.900000     114.000000
# max    47499.000000      2023.000000     10.000000     808.000000
#
#           Metascore
# count  12574.000000
# mean      55.933752
# std       17.320990
# min        1.000000
# 25%       44.000000
# 50%       57.000000
# 75%       69.000000
# max      100.000000

# %%
df['Metascore'].mode()
# Out:
# 0    65.0
# Name: Metascore, dtype: float64

# %%
df.describe()
# Out:
#          Unnamed: 0  Year_of_Release        Rating  Movie_runtime  \
# count  40524.000000     40517.000000  38203.000000   38021.000000
# mean   23452.044393      2014.229262      5.985399     103.305384
# std    14480.130257         9.257136      1.352948      23.185477
# min        0.000000      1972.000000      1.000000       1.000000
# 25%    10366.750000      2010.000000      5.200000      90.000000
# 50%    23310.500000      2017.000000      6.100000      99.000000
# 75%    36876.250000      2021.000000      6.900000     114.000000
# max    47499.000000      2023.000000     10.000000     808.000000
#
#           Metascore
# count  12574.000000
# mean      55.933752
# std       17.320990
# min        1.000000
# 25%       44.000000
# 50%       57.000000
# 75%       69.000000
# max      100.000000

# %%
df[df['Rating']>7]['Rating'].unique()
# Out:
# array([ 9.3,  9. ,  8.8,  8.9,  8.7,  9.2,  8.4,  8.6,  8.5,  8.2,  8.3,
#         8. ,  7.9,  8.1,  7.2,  7.8,  7.3,  7.1,  7.4,  7.7,  7.6,  7.5,
#         9.1,  9.9,  9.6,  9.7,  9.4,  9.8, 10. ,  9.5])

# %%
df[df['Rating']<7]['Metascore'].mode()
# Out:
# 0    49.0
# Name: Metascore, dtype: float64

# %%
df[df['Rating']==9]['Metascore'].mode()
# Out:
# 0    66.0
# 1    84.0
# 2    90.0
# 3    94.0
# 4    95.0
# Name: Metascore, dtype: float64

# %%
self_employed_dict = {1.9:14, 1.2:14, 1.0:14 , 1.6:14, 1.5:14, 1.7:14, 1.3:14, 1.8:14, 1.4:14, 1.1:14,9.3:82,  9.2:82,  9.5:82,  9.4:82,  9.8:82,  9.7:82,  9.1:82,  9.6:82, 10.0:82 ,  9.9:82, 4.2:27, 4.8:27, 3.8:27, 4.9:27, 4.3:27, 4.0:27 , 4.6:27, 3.4:27, 3.1:27, 2.8:27, 2.4:27,4.7:27, 3.3:27, 3.6:27, 4.5:27, 3.9:27, 4.4:27, 2.5:27, 3.5:27,4.1:27, 2.7:27, 2.2:27, 2.0:27 ,
       3.7:27, 2.6:27, 3.0:27, 2.1:27, 3.2:27, 2.9:27, 2.3:27, 8.4:78,  8.6:85,  8.5:85,  8.2:78,  8.3:78,
        8.0:78 ,  7.9:78,  8.1:78,  7.2:65,  7.8:65,  7.3:65,  7.0:65 ,  7.1:65,  6.9:65,  7.4:65,  7.7:78,
        7.6:65,  6.5:54,  7.5:65,  6.6:65,  6.4:49,  6.8:65,  5.9:49,  6.3:54,  6.7:65,  6.2:54,  5.3:49,
        6.1:54,  5.8:49,  5.7:49,  5.6:49,  5.5:49,  6.0:54 ,  5.4:49,  5.1:49,  5.2:49,  8.8:85,  8.9:85,  8.7:85,5.0:49,9.0:90 }
df['Metascore'] = df['Metascore'].fillna(df['Rating'].map(self_employed_dict))

# %%
df[df['Metascore'].isnull()]
# Out:
#        Unnamed: 0                                Title  Year_of_Release  \
# 10995       11286                    Tales of the City           2021.0
# 11015       11307                       Possessed Love           2021.0
# 11043       11335                               Sakshi           2021.0
# 11090       11383                          Pain Killer           2021.0
# 11138       11431  The Hellenback's Alex in Wonderland           2021.0
# ...           ...                                  ...              ...
# 40493       47469                               Status           2023.0
# 40501       47477                                Oliva           2023.0
# 40506       47482                           Spellbound           2023.0
# 40509       47485                 A Song from the Dark           2023.0
# 40512       47488                           Ready Cash           2023.0
#
#        Rating  Movie_runtime Certified                   Genre  Metascore  \
# ...

# %%
df =df.dropna(subset = ['Rating','Genre','Stars','Movie_director','Year_of_Release'])
df
# Out:
#        Unnamed: 0                           Title  Year_of_Release  Rating  \
# 0               0        The Shawshank Redemption           1994.0     9.3
# 1               1                 The Dark Knight           2008.0     9.0
# 2               2                       Inception           2010.0     8.8
# 3               3                      Fight Club           1999.0     8.8
# 4               4                    Forrest Gump           1994.0     8.8
# ...           ...                             ...              ...     ...
# 40519       47495                  Before You Die           2022.0     8.3
# 40520       47496  Tina & Bettina 2: The Comeback           2023.0     5.0
# 40521       47497              Woman in the Chair           2022.0     5.1
# 40522       47498                        Chrzciny           2022.0     5.9
# 40523       47499                          Barren           2022.0     8.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Title                 0
# Year_of_Release       0
# Rating                0
# Movie_runtime      1278
# Certified             0
# Genre                 0
# Metascore             0
# Movie_director        0
# Stars                 0
# Description           0
# Image                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37764 entries, 0 to 40523
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       37764 non-null  int64
#  1   Title            37764 non-null  object
#  2   Year_of_Release  37764 non-null  float64
#  3   Rating           37764 non-null  float64
#  4   Movie_runtime    36486 non-null  float64
#  5   Certified        37764 non-null  object
#  6   Genre            37764 non-null  object
#  7   Metascore        37764 non-null  float64
#  8   Movie_director   37764 non-null  object
#  9   Stars            37764 non-null  object
#  10  Description      37764 non-null  object
#  11  Image            37764 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 3.7+ MB

# %%
g=[]
for i in df['Stars']:
    t = i.split(', ')
    g.append(t)
g
# Out:
# [['Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler'],
#  ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'],
#  ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page', 'Ken Watanabe'],
#  ['Brad Pitt', 'Edward Norton', 'Meat Loaf', 'Zach Grenier'],
#  ['Tom Hanks', 'Robin Wright', 'Gary Sinise', 'Sally Field'],
#  ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson', 'Bruce Willis'],
#  ['Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss', 'Hugo Weaving'],
#  ['Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain', 'Mackenzie Foy'],
#  ['Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton'],
#  ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom', 'Sean Bean'],
#  ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen', 'Orlando Bloom'],
#  ['Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman'],
#  ['Morgan Freeman', 'Brad Pitt', 'Kevin Spacey', 'Andrew Kevin Walker'],
# ...

# %%
def details(column,list_name):
    cast = df[column].unique()
    list_cast = []
    for d in cast:
        list_cast += d.split(',')
    all_cast=[]
    for l in list_cast:
        all_cast.append(l.replace(' ',''))
    for x in all_cast:
        if x not in list_name:
            list_name.append(x)

# %%
len(star)
# Out:
# 24080

# %%
df
# Out:
#        Unnamed: 0                           Title  Year_of_Release  Rating  \
# 0               0        The Shawshank Redemption           1994.0     9.3
# 1               1                 The Dark Knight           2008.0     9.0
# 2               2                       Inception           2010.0     8.8
# 3               3                      Fight Club           1999.0     8.8
# 4               4                    Forrest Gump           1994.0     8.8
# ...           ...                             ...              ...     ...
# 40519       47495                  Before You Die           2022.0     8.3
# 40520       47496  Tina & Bettina 2: The Comeback           2023.0     5.0
# 40521       47497              Woman in the Chair           2022.0     5.1
# 40522       47498                        Chrzciny           2022.0     5.9
# 40523       47499                          Barren           2022.0     8.0
#
# ...

# %%
df = df.reset_index()
df
# Out:
#        index  Unnamed: 0                           Title  Year_of_Release  \
# 0          0           0        The Shawshank Redemption           1994.0
# 1          1           1                 The Dark Knight           2008.0
# 2          2           2                       Inception           2010.0
# 3          3           3                      Fight Club           1999.0
# 4          4           4                    Forrest Gump           1994.0
# ...      ...         ...                             ...              ...
# 37759  40519       47495                  Before You Die           2022.0
# 37760  40520       47496  Tina & Bettina 2: The Comeback           2023.0
# 37761  40521       47497              Woman in the Chair           2022.0
# 37762  40522       47498                        Chrzciny           2022.0
# 37763  40523       47499                          Barren           2022.0
#
#        Rating  Movie_runtime Certified                      Genre  Metascore  \
# ...

# %%
df = df.drop(columns = ['index','Unnamed: 0'])
df
# Out:
#                                 Title  Year_of_Release  Rating  Movie_runtime  \
# 0            The Shawshank Redemption           1994.0     9.3          142.0
# 1                     The Dark Knight           2008.0     9.0          152.0
# 2                           Inception           2010.0     8.8          148.0
# 3                          Fight Club           1999.0     8.8          139.0
# 4                        Forrest Gump           1994.0     8.8          142.0
# ...                               ...              ...     ...            ...
# 37759                  Before You Die           2022.0     8.3            NaN
# 37760  Tina & Bettina 2: The Comeback           2023.0     5.0           90.0
# 37761              Woman in the Chair           2022.0     5.1            NaN
# 37762                        Chrzciny           2022.0     5.9           88.0
# 37763                          Barren           2022.0     8.0          108.0
#
# ...

# %%
for index, row in df.iterrows():
    if nit in row['Stars']:
        try:
            if row['Metascore']>80:
                try:
                    if row['Rating'] >rat:
                        print(row['Title'])
                except:
                    print(row['Title'])
        except:
            print(row['Title'])
    else:
        r = nit
# Out:
# The Dark Knight
# American Hustle
# The Big Short
# Ford v Ferrari

# %%
stars = []
genre = []
director = []
details(column='Stars', list_name=stars)
details(column='Movie_director', list_name=director)
details(column='Genre', list_name=genre)
print(len(stars), len(director), len(genre))
# Out:
# 71414 24080 22

# %%
df.head()
# Out:
#                       Title  Year_of_Release  Rating  Movie_runtime Certified  \
# 0  The Shawshank Redemption           1994.0     9.3          142.0       U/A
# 1           The Dark Knight           2008.0     9.0          152.0       U/A
# 2                 Inception           2010.0     8.8          148.0       U/A
# 3                Fight Club           1999.0     8.8          139.0       U/A
# 4              Forrest Gump           1994.0     8.8          142.0       U/A
#
#                        Genre  Metascore     Movie_director  \
# 0                      Drama       82.0     Frank Darabont
# 1       Action, Crime, Drama       84.0  Christopher Nolan
# 2  Action, Adventure, Sci-Fi       74.0  Christopher Nolan
# 3                      Drama       67.0      David Fincher
# 4             Drama, Romance       82.0    Robert Zemeckis
#
#                                                Stars  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# ...

# %%
df.to_csv('pictures.csv')

# %%
df.head()
# Out:
#                       Title  Year_of_Release  Rating  Movie_runtime Certified  \
# 0  The Shawshank Redemption           1994.0     9.3          142.0       U/A
# 1           The Dark Knight           2008.0     9.0          152.0       U/A
# 2                 Inception           2010.0     8.8          148.0       U/A
# 3                Fight Club           1999.0     8.8          139.0       U/A
# 4              Forrest Gump           1994.0     8.8          142.0       U/A
#
#                            Genre  Metascore       Movie_director  \
# 0                        [Drama]       82.0     [Frank Darabont]
# 1       [Action,  Crime,  Drama]       84.0  [Christopher Nolan]
# 2  [Action,  Adventure,  Sci-Fi]       74.0  [Christopher Nolan]
# 3                        [Drama]       67.0      [David Fincher]
# 4              [Drama,  Romance]       82.0    [Robert Zemeckis]
#
#                                                Stars  \
# ...

# %%
df['Stars'][0]
# Out:
# ['Tim_Robbins', 'Morgan_Freeman', 'Bob_Gunton', 'William_Sadler']

# %%
a = []

# %%
def titles():
    for index, row in df.iterrows():
        if
