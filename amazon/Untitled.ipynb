# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import requests
from bs4 import BeautifulSoup

# %%
datainput = input('chose your product')
# Out:
# chose your productlaptop

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
name = []
price=[]
rating = []
image = []
stars = []
arrival = []
last_buy = []
for number in range(0,3):
    webpage= ""
    string = requests.get(f'https://www.amazon.in/s?k={datainput}&page={number}&ref=sr_pg_1', headers =headers).text
    webpage = string + webpage
    soup = BeautifulSoup(webpage, 'html.parser')
    page = soup.find('div', class_='a-section a-spacing-small a-spacing-top-small').text.strip().split(' ')[0].split('-')
    total_item = int(page[1]) - int(page[0])
    total_item = int(total_item)
    if total_item >20:
        products_2 = soup.find_all('div', class_ = 's-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v11f16tn6b5f9e2nrycg91ik6p8 s-latency-cf-section s-card-border')
        for info in products_2:
            try:
                i = info.find('div', class_='a-row a-size-base a-color-base').text.strip()
                price.append(i.split('₹')[1])
            except:
                price.append(np.nan)
            try:
                i = info.find('span', class_='a-size-base s-underline-text').text.strip()
                rating.append(i)
            except:
                rating.append(np.nan)
            try:
                image.append(info.find('img', class_='s-image').get('src'))
            except:
                image.append(np.nan)
            try:
                stars.append(info.find('span', class_='a-icon-alt').text.strip().split(' ')[0])
            except:
                stars.append(np.nan)
            try:
                i = info.find('span', class_='a-color-base a-text-bold').text.strip()
                arrival.append(i)
            except:
                arrival.append('No Date specified')
            try:
                i = info.find('span', class_='a-size-base-plus a-color-base a-text-normal').text.strip()
                name.append(i)
            except:
                name.append(np.nan)
            try:
                i = info.find('span', class_='a-size-base a-color-secondary').text.strip()
                last_buy.append(i)
            except:
                last_buy.append(np.nan)
            len(last_buy)
        dictionary = {'Product': name,'Stars': stars,'Rating': rating,'Image':image,'Price': price,'Delievery_time': arrival,'Previous_buyers': last_buy}

    else:
        products_1 = soup.find_all('div', class_ = 'sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16')
        for info in products_1:
            try:
                i = info.find('span', class_='a-price-whole').text.strip()
                price.append(i)
            except:
                price.append('kalu')
            try:
                i = info.find('span', class_='a-size-base s-underline-text').text.strip()
                rating.append(i)
            except:
                rating.append(np.nan)
            try:
                image.append(info.find('img', class_='s-image').get('src'))
            except:
                image.append(np.nan)
            try:
                stars.append(info.find('span', class_='a-icon-alt').text.strip().split(' ')[0])
            except:
                stars.append(np.nan)
            try:
                i = info.find('span', class_='a-color-base a-text-bold').text.strip()
                arrival.append(i)
            except:
                arrival.append('No Date specified')
            try:
                i = info.find('span', class_='a-size-medium a-color-base a-text-normal').text.strip()
                name.append(i)
            except:
                name.append('Kalu')
        dictionary = {'Product': name,'Stars': stars,'Rating': rating,'Image':image,'Price': price,'Delievery_time': arrival}
    print(len(name),len(stars),len(rating),len(image),len(price),len(arrival),len(last_buy))
# Out:
# 16 16 16 16 16 16 0
# 32 32 32 32 32 32 0
# 48 48 48 48 48 48 0

# %%
page = soup.find('div', class_='a-section a-spacing-small a-spacing-top-small').text.strip().split(' ')[0].split('-')
total_item = int(page[1]) - int(page[0])
total_item = int(total_item)

# %%
if total_item >20:
    products_2 = soup.find_all('div', class_ = 's-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v11f16tn6b5f9e2nrycg91ik6p8 s-latency-cf-section s-card-border')
    last_buy = []
    name = []
    price=[]
    rating = []
    image = []
    stars = []
    arrival = []
    for info in products_2:
        try:
            i = info.find('div', class_='a-row a-size-base a-color-base').text.strip()
            price.append(i.split('₹')[1])
        except:
            price.append(np.nan)
        try:
            i = info.find('span', class_='a-size-base s-underline-text').text.strip()
            rating.append(i)
        except:
            rating.append(np.nan)
        try:
            image.append(info.find('img', class_='s-image').get('src'))
        except:
            image.append(np.nan)
        try:
            stars.append(info.find('span', class_='a-icon-alt').text.strip().split(' ')[0])
        except:
            stars.append(np.nan)
        try:
            i = info.find('span', class_='a-color-base a-text-bold').text.strip()
            arrival.append(i)
        except:
            arrival.append('No Date specified')
        try:
            i = info.find('span', class_='a-size-base-plus a-color-base a-text-normal').text.strip()
            name.append(i)
        except:
            name.append(np.nan)
        try:
            i = info.find('span', class_='a-size-base a-color-secondary').text.strip()
            last_buy.append(i)
        except:
            last_buy.append(np.nan)
        len(last_buy)
    dictionary = {'Product': name,'Stars': stars,'Rating': rating,'Image':image,'Price': price,'Delievery_time': arrival,'Previous_buyers': last_buy}

else:
    products_1 = soup.find_all('div', class_ = 'sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-16-of-20 sg-col s-widget-spacing-small sg-col-12-of-16')
    name = []
    price=[]
    rating = []
    image = []
    stars = []
    arrival = []
    for info in products_1:
        try:
            i = info.find('span', class_='a-price-whole').text.strip()
            price.append(i)
        except:
            price.append('kalu')
        try:
            i = info.find('span', class_='a-size-base s-underline-text').text.strip()
            rating.append(i)
        except:
            rating.append(np.nan)
        try:
            image.append(info.find('img', class_='s-image').get('src'))
        except:
            image.append(np.nan)
        try:
            stars.append(info.find('span', class_='a-icon-alt').text.strip().split(' ')[0])
        except:
            stars.append(np.nan)
        try:
            i = info.find('span', class_='a-color-base a-text-bold').text.strip()
            arrival.append(i)
        except:
            arrival.append('No Date specified')
        try:
            i = info.find('span', class_='a-size-medium a-color-base a-text-normal').text.strip()
            name.append(i)
        except:
            name.append('Kalu')
    dictionary = {'Product': name,'Stars': stars,'Rating': rating,'Image':image,'Price': price,'Delievery_time': arrival}
print(len(name),len(stars),len(rating),len(image),len(price),len(arrival),len(last_buy))
# Out:
# 60 60 60 60 60 60 60

# %%
stars
# Out:
# ['3.9',
#  '3.8',
#  '4.0',
#  '2.8',
#  '4.7',
#  '3.8',
#  '4.0',
#  '3.0',
#  '3.9',
#  '4.3',
#  '4.0',
#  '4.2',
#  '4.0',
#  '3.9',
#  '4.2',
#  '4.1',
#  '3.9',
#  '3.8',
#  '4.0',
#  '2.8',
#  '4.7',
#  '3.8',
#  '4.0',
#  '3.0',
#  '3.9',
#  '4.3',
#  '4.0',
#  '4.2',
#  '4.0',
#  '3.7',
#  '4.2',
#  '4.0',
#  '3.1',
#  '3.9',
#  '4.0',
#  '4.3',
#  '4.0',
#  '4.0',
#  nan,
#  '4.2',
#  '3.8',
#  '5.0',
#  '4.7',
#  '2.7',
#  nan,
#  '2.9',
#  '2.9',
#  nan]

# %%
print(len(name),len(stars),len(rating),len(image),len(price),len(arrival),len(last_buy))
# Out:
# 48 48 48 48 48 48 0

# %%
df = pd.DataFrame(dictionary)
df.tail(10)
# Out:
#                                               Product Stars   Rating  \
# 0   ASUS [SmartChoice] Vivobook 15, Intel Celeron ...   3.9    1,045
# 1   Acer Aspire Lite 11th Gen Intel Core i3 Premiu...   3.8       66
# 2   ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...   4.0      263
# 3   JioBook 11 (2023) NB1112MM(BLU) (Mediatek 8788...   2.8       64
# 4   Apple MacBook Air Laptop M1 chip, 13.3-inch/33...   4.7    3,027
# 5   Acer Aspire Lite 11th Gen Intel Core i3-1115G4...   3.8       66
# 6   Dell 14 Laptop, Intel Core 11th Gen i3-1115G4/...   4.0      205
# 7   HP Laptop 15s, Intel Celeron N4500, 15.6 inch(...   3.0       35
# 8   Dell 14 Laptop, Intel Core i5-1135G7 Processor...   3.9       31
# 9   ASUS Vivobook Pro 15,AMD Ryzen 5 5600H,15.6" (...   4.3       88
# 10  HP Laptop 14s, 12th Gen Intel Core i3-1215U, 1...   4.0    1,217
# 11  ASUS [SmartChoice] Vivobook 16X (2022), 16-inc...   4.2      633
# 12  Acer Aspire 5 Gaming Laptop Intel Core i5 12th...   4.0      607
# 13  Acer Aspire Lite AMD Ryzen 5 5500U Premium Thi...   3.9       54
# 14  Xiaomi Notebook Ultra Max 11th Gen Intel Core ...   4.2    2,033
# 15  HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...   4.1    1,608
# 16  ASUS [SmartChoice] Vivobook 15, Intel Celeron ...   3.9    (1K+)
# 17  Acer Aspire Lite 11th Gen Intel Core i3 Premiu...   3.8     (66)
# 18  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...   4.0    (263)
# 19  JioBook 11 (2023) NB1112MM(BLU) (Mediatek 8788...   2.8     (64)
# 20  Apple MacBook Air Laptop M1 chip, 13.3-inch/33...   4.7    (3K+)
# 21  Acer Aspire Lite 11th Gen Intel Core i3-1115G4...   3.8     (66)
# 22  Dell 14 Laptop, Intel Core 11th Gen i3-1115G4/...   4.0    (205)
# 23  HP Laptop 15s, Intel Celeron N4500, 15.6 inch(...   3.0     (35)
# 24  Dell 14 Laptop, Intel Core i5-1135G7 Processor...   3.9     (31)
# 25  ASUS Vivobook Pro 15,AMD Ryzen 5 5600H,15.6" (...   4.3     (88)
# 26  HP Laptop 14s, 12th Gen Intel Core i3-1215U, 1...   4.0  (1.2K+)
# 27  ASUS [SmartChoice] Vivobook 16X (2022), 16-inc...   4.2    (633)
# 28  Acer Aspire 5 Gaming Laptop Intel Core i5 12th...   4.0    (607)
# 29  Dell 14 Laptop, Intel Core i5-1135G7 Processor...   3.7    (102)
# 30  Xiaomi Notebook Ultra Max 11th Gen Intel Core ...   4.2    (2K+)
# 31  ASUS Vivobook 14, Intel Core i3-1115G4 11th Ge...   4.0    (229)
# 32  HP 250 G8 (6G9R1PA) Laptop (Intel Core i3/ 11t...   3.1       15
# 33  ASUS Vivobook 14, IntelCore i3-1215U 12th Gen,...   3.9      225
# 34  HP Chromebook X360,Intel Celeron N4120,14-Inch...   4.0      161
# 35  Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...   4.3      525
# 36  Lenovo IdeaPad 1 Intel Core Celeron N4020 14" ...   4.0        5
# 37  HP Chromebook X360 Intel Celeron N4020 14 inch...   4.0      161
# 38  ASUS Vivobook 15, IntelCore i3-1215U 12th Gen,...   NaN      NaN
# 39  HONOR MagicBook 14, AMD Ryzen 5 5500U 14-inch ...   4.2      346
# 40  HP 255 G8 Laptop with AMD Athlon Silver 3050U ...   3.8        5
# 41  HP Laptop 15s, Intel Pentium Silver N6000, 15....   5.0        1
# 42  HP 255 G8 Laptop (15.6-inch) FHD (Ryzen 3-3250...   4.7       11
# 43  MSI Titan GT77 HX, Intel 13th Gen. i9-13980HX,...   2.7       10
# 44  HP Omen 12th Gen Intel Core i7-12700H 16.1 inc...   NaN      NaN
# 45  Asus Rog Strix Scar 15 (2022) 15.6 Inches 2K W...   2.9       10
# 46  Acer Predator Helios 16 Gaming Laptop (Intel C...   2.9        5
# 47  HP ZBook Studio 12th Gen Intel Core i9-12900H ...   NaN      NaN
#
#                                                 Image     Price  \
# 0   https://m.media-amazon.com/images/I/71dAYFhRTc...    28,990
# 1   https://m.media-amazon.com/images/I/617rprfdhR...    31,990
# 2   https://m.media-amazon.com/images/I/718-NoktzD...    59,990
# 3   https://m.media-amazon.com/images/I/51cNQIk3q9...    16,499
# 4   https://m.media-amazon.com/images/I/71TPda7cwU...    81,990
# 5   https://m.media-amazon.com/images/I/71czGb00k5...    30,990
# 6   https://m.media-amazon.com/images/I/51cW1H73uV...    36,490
# 7   https://m.media-amazon.com/images/I/811aBK9bUF...    28,990
# 8   https://m.media-amazon.com/images/I/51hEf-tkHr...    52,490
# 9   https://m.media-amazon.com/images/I/61eTPcEsC+...    65,990
# 10  https://m.media-amazon.com/images/I/71XySD6YwE...    40,990
# 11  https://m.media-amazon.com/images/I/71KNOlOOI-...    46,990
# 12  https://m.media-amazon.com/images/I/61xzutxSl8...    54,990
# 13  https://m.media-amazon.com/images/I/71czGb00k5...    37,990
# 14  https://m.media-amazon.com/images/I/710aJMxsUX...    48,990
# 15  https://m.media-amazon.com/images/I/71Dp4q8Pbi...    39,490
# 16  https://m.media-amazon.com/images/I/71dAYFhRTc...    28,990
# 17  https://m.media-amazon.com/images/I/617rprfdhR...    31,990
# 18  https://m.media-amazon.com/images/I/718-NoktzD...    59,990
# 19  https://m.media-amazon.com/images/I/51cNQIk3q9...    16,499
# 20  https://m.media-amazon.com/images/I/71TPda7cwU...    81,990
# 21  https://m.media-amazon.com/images/I/71czGb00k5...    30,990
# 22  https://m.media-amazon.com/images/I/51cW1H73uV...    36,490
# 23  https://m.media-amazon.com/images/I/811aBK9bUF...    28,990
# 24  https://m.media-amazon.com/images/I/51hEf-tkHr...    52,490
# 25  https://m.media-amazon.com/images/I/61eTPcEsC+...    65,990
# 26  https://m.media-amazon.com/images/I/71XySD6YwE...    40,990
# 27  https://m.media-amazon.com/images/I/71KNOlOOI-...    46,990
# 28  https://m.media-amazon.com/images/I/61xzutxSl8...    54,990
# 29  https://m.media-amazon.com/images/I/51hEf-tkHr...    48,990
# 30  https://m.media-amazon.com/images/I/710aJMxsUX...    48,990
# 31  https://m.media-amazon.com/images/I/716x1581Ir...    34,990
# 32  https://m.media-amazon.com/images/I/71V2Q8g87X...    35,990
# 33  https://m.media-amazon.com/images/I/71hu2MKb3x...    37,990
# 34  https://m.media-amazon.com/images/I/71NVgWIF+G...    26,990
# 35  https://m.media-amazon.com/images/I/71tHNTGasK...    41,990
# 36  https://m.media-amazon.com/images/I/71VmRFFkrs...    24,990
# 37  https://m.media-amazon.com/images/I/71Rhg4BxH2...    24,990
# 38  https://m.media-amazon.com/images/I/71qTbS09tj...    38,990
# 39  https://m.media-amazon.com/images/I/71tHNTGasK...    37,990
# 40  https://m.media-amazon.com/images/I/81GtQFQq-L...    22,990
# 41  https://m.media-amazon.com/images/I/71xqaCeW45...    32,990
# 42  https://m.media-amazon.com/images/I/411USHhK-2...    29,990
# 43  https://m.media-amazon.com/images/I/71yWBoj2ku...  4,65,990
# 44  https://m.media-amazon.com/images/I/51UAd405cW...  1,58,990
# 45  https://m.media-amazon.com/images/I/716tZo4diQ...  2,39,990
# 46  https://m.media-amazon.com/images/I/71xA3i5-hf...  2,49,990
# 47  https://m.media-amazon.com/images/I/716oJNJFLA...  3,47,990
#
#        Delievery_time
# 0        Tue, 12 Sept
# 1        Tue, 12 Sept
# 2        Sun, 10 Sept
# 3        Sun, 10 Sept
# 4        Sun, 10 Sept
# 5        Sun, 10 Sept
# 6        Sun, 10 Sept
# 7        Sun, 10 Sept
# 8        Sun, 10 Sept
# 9        Tue, 12 Sept
# 10       Sun, 10 Sept
# 11       Sun, 10 Sept
# 12       Sun, 10 Sept
# 13       Tue, 12 Sept
# 14       Sun, 10 Sept
# 15       Sun, 10 Sept
# 16       Tue, 12 Sept
# 17       Tue, 12 Sept
# 18       Sun, 10 Sept
# 19       Sun, 10 Sept
# 20       Sun, 10 Sept
# 21       Sun, 10 Sept
# 22       Sun, 10 Sept
# 23       Sun, 10 Sept
# 24       Sun, 10 Sept
# 25       Tue, 12 Sept
# 26       Sun, 10 Sept
# 27       Sun, 10 Sept
# 28       Sun, 10 Sept
# 29       Sun, 10 Sept
# 30       Sun, 10 Sept
# 31       Sun, 10 Sept
# 32       Tue, 12 Sept
# 33       Sun, 10 Sept
# 34       Sun, 10 Sept
# 35       Sun, 10 Sept
# 36       Sun, 10 Sept
# 37  No Date specified
# 38       Sun, 10 Sept
# 39       Sun, 10 Sept
# 40       Tue, 12 Sept
# 41       Sun, 10 Sept
# 42       Tue, 12 Sept
# 43       Sun, 10 Sept
# 44       Tue, 12 Sept
# 45       Tue, 12 Sept
# 46       Sun, 10 Sept
# 47       Sun, 10 Sept
